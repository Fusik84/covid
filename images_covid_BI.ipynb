# %% [markdown]
# <a href="https://colab.research.google.com/github/Fusik84/covid/blob/main/images_covid_BI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
image = mpimg.imread ('noname1.png')
plt.figure(figsize=(15,6))
plt.axis('off')
plt.imshow(image)

# %%
image = mpimg.imread ('noname2.png')
plt.figure(figsize=(15,6))
plt.axis('off')
plt.imshow(image)

# %%
image = mpimg.imread ('noname3.png')
plt.figure(figsize=(15,6))
plt.axis('off')
plt.imshow(image)

# %%
image = mpimg.imread ('noname4.png')
plt.figure(figsize=(15,6))
plt.axis('off')
plt.imshow(image)

# %%
image = mpimg.imread ('noname5.png')
plt.figure(figsize=(15,6))
plt.axis('off')
plt.imshow(image)

# %%
image = mpimg.imread ('noname.png')
plt.figure(figsize=(15,6))
plt.axis('off')
plt.imshow(image)
